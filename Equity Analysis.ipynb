# %%
import pandas as pd 
msft = pd.read_csv('MSFT.csv')

# %%
msft.head()
# Out:
#          Date       Open       High        Low  Close  Adj Close    Volume
# 0  2010-04-01  29.350000  29.540001  28.620001  29.16  22.712545  74768100
# 1  2010-04-05  29.129999  29.430000  29.030001  29.27  22.798235  34331200
# 2  2010-04-06  29.150000  29.580000  28.980000  29.32  22.837175  47366800
# 3  2010-04-07  29.160000  29.559999  29.139999  29.35  22.860538  58318800
# 4  2010-04-08  29.320000  29.980000  29.299999  29.92  23.304508  63713800

# %%
msft = pd.read_csv('MSFT.csv', header=0, index_col='Date', parse_dates=True)

# %%
msft
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-04-01   29.350000   29.540001   28.620001   29.160000   22.712545
# 2010-04-05   29.129999   29.430000   29.030001   29.270000   22.798235
# 2010-04-06   29.150000   29.580000   28.980000   29.320000   22.837175
# 2010-04-07   29.160000   29.559999   29.139999   29.350000   22.860538
# 2010-04-08   29.320000   29.980000   29.299999   29.920000   23.304508
# ...                ...         ...         ...         ...         ...
# 2019-03-25  116.559998  118.010002  116.320000  117.660004  114.690613
# 2019-03-26  118.620003  118.709999  116.849998  117.910004  114.934296
# 2019-03-27  117.879997  118.209999  115.519997  116.769997  113.823051
# 2019-03-28  117.440002  117.580002  116.129997  116.930000  113.979027
# 2019-03-29  118.070000  118.320000  116.959999  117.940002  114.963547
#
#               Volume
# Date
# 2010-04-01  74768100
# 2010-04-05  34331200
# 2010-04-06  47366800
# ...

# %%
# !pip install pandas_datareader
# Out:
# ...
# WARNING: Error parsing requirements for singledispatch: [Errno 2] No such file or directory: 'c:\\users\\prajw\\anaconda3\\lib\\site-packages\\singledispatch-3.4.0.3.dist-info\\METADATA'

# %%
import pandas_datareader as pdr
import datetime

# %%
nvda = pdr.get_data_yahoo('NVDA', 
                          start=datetime.datetime(2010, 3, 31), 
                          end=datetime.datetime(2019, 3, 30))

# %%
qcom = pdr.get_data_yahoo('QCOM',
                         start=datetime.datetime(2010, 3, 31), 
                          end=datetime.datetime(2019, 3, 30))

# %%
intc = pdr.get_data_yahoo('INTC',
                         start=datetime.datetime(2010, 3, 31), 
                          end=datetime.datetime(2019, 3, 30))

# %%
ibm = pdr.get_data_yahoo('IBM',
                        start=datetime.datetime(2010, 3, 31), 
                          end=datetime.datetime(2019, 3, 30))

# %%
type(qcom)
# Out:
# pandas.core.frame.DataFrame

# %%
qcom.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2010-03-31  42.220001  41.840000  41.990002  41.959999  14932000.0  31.058010
# 2010-04-01  42.459999  42.139999  42.169998  42.270000  16319600.0  31.287458
# 2010-04-05  43.009998  42.389999  42.599998  42.529999  14692200.0  31.479904
# 2010-04-06  42.560001  42.189999  42.220001  42.430000  10067800.0  31.405890
# 2010-04-07  42.869999  42.369999  42.369999  42.770000  16091300.0  31.657557

# %%
qcom.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  2265.000000  2265.000000  2265.000000  2265.000000  2.265000e+03
# mean     60.584419    59.462194    60.026967    60.032817  1.269104e+07
# std       9.867351     9.855850     9.854640     9.863312  7.279870e+06
# min      32.680000    31.629999    31.870001    31.959999  2.451300e+06
# 25%      53.939999    52.880001    53.439999    53.419998  8.373000e+06
# 50%      60.230000    59.070000    59.700001    59.680000  1.108240e+07
# 75%      67.419998    66.230003    66.790001    66.839996  1.471510e+07
# max      81.970001    81.419998    81.889999    81.599998  9.691660e+07
#
#          Adj Close
# count  2265.000000
# mean     49.060369
# std       8.779010
# min      23.783083
# 25%      43.601326
# 50%      49.475056
# 75%      56.212982
# max      69.163391

# %%
qcom.shape
# Out:
# (2265, 6)

# %% [markdown]
# **TIME SERIES DATA**
# A time series is a sequence of numerical data points taken at successive equally spaced points in time.
# Here, a time series tracks the movement of stock price, over a specified period of time.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.dates as mdates

# %%
plt.plot(msft.index, msft['Adj Close'])
plt.grid(True)
plt.xticks(rotation=0)
plt.show()

# %%
f, ax = plt.subplots(2, 2, figsize=(10,10), sharex=True)
f.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
f.gca().xaxis.set_major_locator(mdates.YearLocator())

ax[0,0].plot(nvda.index, nvda['Adj Close'], color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('NVIDIA');

ax[1,0].plot(intc.index, intc['Adj Close'], color='y')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('INTEL');

ax[1,1].plot(qcom.index, qcom['Adj Close'], color='b')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('QUALCOMM');

ax[0,1].plot(msft.index, msft['Adj Close'], color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('msft');

# %% [markdown]
# **Close-up**

# %%
msft_2014 = msft.loc[pd.Timestamp('2014-01-01'):pd.Timestamp('2014-12-31')]
plt.plot(msft_2014.index, msft_2014['Adj Close'])
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
#Subplots
f, ax = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True)
f.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
f.gca().xaxis.set_major_locator(mdates.MonthLocator())

nvda_14 = nvda.loc[pd.Timestamp('2014-01-01'):pd.Timestamp('2014-12-31')]
ax[0,0].plot(nvda_14.index, nvda_14['Adj Close'], '.', color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('NVIDIA');

intc_14 = intc.loc[pd.Timestamp('2014-01-01'):pd.Timestamp('2014-12-31')]
ax[0,1].plot(intc_14.index, intc_14['Adj Close'], '.' ,color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('INTEL');

qcom_14 = qcom.loc[pd.Timestamp('2014-01-01'):pd.Timestamp('2014-12-31')]
ax[1,0].plot(qcom_14.index, qcom_14['Adj Close'], '.' ,color='b')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('QUALCOMM');

msft_18 = msft.loc[pd.Timestamp('2014-01-01'):pd.Timestamp('2014-12-31')]
ax[1,1].plot(msft_18.index, msft_18['Adj Close'], '.' ,color='y')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('MSFT');

# %% [markdown]
# **WEEKLY RESAMPLING**

# %%
msft_2014 = msft.loc[pd.Timestamp('2014-01-01'):pd.Timestamp('2014-08-31')]
weekly_msft_2014 = msft_2014.resample('W').mean()
weekly_msft_2014.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2014-01-05  37.274999  37.310001  36.849998  37.035000  31.875889  30883500
# 2014-01-12  36.192001  36.316000  35.810001  35.974000  30.962691  43288660
# 2014-01-19  36.028001  36.504001  35.554001  36.157999  31.121061  43324800
# 2014-01-26  36.655000  36.705000  35.965000  36.242500  31.193790  43455275
# 2014-02-02  36.542000  36.986000  36.084001  36.732000  31.615102  52314160

# %%
plt.plot(weekly_msft_2014.index, weekly_msft_2014['Adj Close'], '-o')

# %%
nvda_14 = nvda.loc[pd.Timestamp('2019-01-15'):pd.Timestamp('2019-09-15')]
weekly_nvda_14 = nvda_14.resample('W').mean()

intc_14 = intc.loc[pd.Timestamp('2019-01-15'):pd.Timestamp('2019-09-15')]
weekly_intc_14 = intc_14.resample('W').mean()

qcom_14 = qcom.loc[pd.Timestamp('2019-01-15'):pd.Timestamp('2019-09-15')]
weekly_qcom_14 = qcom_14.resample('W').mean()

msft_14 = msft.loc[pd.Timestamp('2019-01-15'):pd.Timestamp('2019-09-15')]
weekly_msft_14 = msft_14.resample('W').mean()

f, ax = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True)
ax[0,0].plot(weekly_nvda_14.index, weekly_nvda_14['Adj Close'], '-o', color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('NVIDIA');

ax[0,1].plot(weekly_intc_14.index, weekly_intc_14['Adj Close'], '-o',color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('INTEL');

ax[1,0].plot(weekly_qcom_14.index, weekly_qcom_14['Adj Close'],'-o', color='b')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('QUALCOMM');

ax[1,1].plot(weekly_msft_14.index, weekly_msft_14['Adj Close'], '-o', color='y')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('MSFT');

# %% [markdown]
# **MOVING WINDOWS** - **Daily percentages**

# %%
daily_close_msft = msft[['Adj Close']]
#Daily returns
daily_pct_change_msft = daily_close_msft.pct_change()

# Clean data: Replace null values with 0
daily_pct_change_msft.fillna(0,inplace=True)
daily_pct_change_msft.head()
# Out:
#             Adj Close
# Date
# 2010-04-01   0.000000
# 2010-04-05   0.003773
# 2010-04-06   0.001708
# 2010-04-07   0.001023
# 2010-04-08   0.019421

# %%
daily_pct_change_msft.hist(bins=100)
plt.show()

# %%
daily_close_nvda = nvda[['Adj Close']]

# Daily returns
daily_pct_change_nvda = daily_close_nvda.pct_change()

# Replace NA values with 0
daily_pct_change_nvda.fillna(0, inplace=True)

daily_close_intc = intc[['Adj Close']]

# Daily returns
daily_pct_change_intc = daily_close_intc.pct_change()

# Replace NA values with 0
daily_pct_change_intc.fillna(0, inplace=True)

daily_close_qcom = qcom[['Adj Close']]

# Daily returns
daily_pct_change_qcom = daily_close_qcom.pct_change()

# Replace NA values with 0
daily_pct_change_qcom.fillna(0, inplace=True)

daily_close_msft = msft[['Adj Close']]

# Daily returns
daily_pct_change_msft = daily_close_msft.pct_change()

# Replace NA values with 0
daily_pct_change_msft.fillna(0, inplace=True)

# %%
import seaborn as sns
# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(12, 7))

sns.distplot(daily_pct_change_nvda['Adj Close'], color="b", ax=axes[0, 0], axlabel='NVIDIA');
sns.distplot(daily_pct_change_intc['Adj Close'], color="r", ax=axes[0, 1], axlabel='INTEL');
sns.distplot(daily_pct_change_qcom['Adj Close'], color="g", ax=axes[1, 0], axlabel='QUALCOMM');
sns.distplot(daily_pct_change_msft['Adj Close'], color="m", ax=axes[1, 1], axlabel='MSFT');
# Out:
# C:\Users\Prajw\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Prajw\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# **VOLATALITY PRESENCE**

# %%
import numpy as np 
min_periods = 75
#Calculating the volatility 
vol = daily_pct_change_msft.rolling(min_periods).std()*np.sqrt(min_periods)
vol.fillna(0,inplace = True)
vol.tail()
# Out:
#             Adj Close
# Date
# 2019-03-25   0.163486
# 2019-03-26   0.160087
# 2019-03-27   0.160385
# 2019-03-28   0.154870
# 2019-03-29   0.152999

# %%
# pictorial representation of the volatility in MSFT
vol.plot(figsize=(10,8))
plt.show()

# %% [markdown]
# **TRENDS AND SEASONALITY**

# %%
ibm_adj_close_price = ibm['Adj Close']
# Short moving window rolling mean
ibm['42'] = ibm_adj_close_price.rolling(window=42).mean()

# Long moving window rolling mean
ibm['252'] = ibm_adj_close_price.rolling(window=252).mean()

# Plot the adjusted closing price, the short and long windows of rolling means
ibm[['Adj Close', '42', '252']].plot(title="IBM")

# Show plot
plt.show()

nvda_adj_close_price = nvda['Adj Close']
# Short moving window rolling mean
nvda['42'] = nvda_adj_close_price.rolling(window=42).mean()

# Long moving window rolling mean
nvda['252'] = nvda_adj_close_price.rolling(window=252).mean()

# Plot the adjusted closing price, the short and long windows of rolling means
nvda[['Adj Close', '42', '252']].plot(title="NVIDIA")

# Show plot
plt.show()

# %%
ibm.loc['2019-01-01':'2019-09-15'][['Adj Close', '42', '252']].plot(title="IBM in 2019");
nvda.loc['2019-01-01':'2019-09-15'][['Adj Close', '42', '252']].plot(title="NVIDIA in 2019");
